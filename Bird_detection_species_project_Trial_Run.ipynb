# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Library imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split

# %%
# !ls "/content/drive/MyDrive"
# Out:
#  15EC101_basic_electronics_engineering.pdf
# 'Bird Speciees Dataset'
#  bird_species.h5
# 'Call recording I-Mom_191001_173628.m4a'
#  Classroom
# 'Colab Notebooks'
# 'Data (1).gdoc'
#  Data.gdoc
#  hackerrank.gdoc
#  Invoice.pdf
# 'IOT SECOND YEAR.gsheet'
# 'iuo-xwmb-drh – 31 Jan 2021.gjam'
# 'Microsoft '
# 'SpiceJet_Mobile_PNR MD9JQD - 14 Aug 2019 Chennai-Delhi for MS. ARYA.PNG'
#  Ticket_9405116490.pdf
# 'Untitled document.gdoc'
# 'Untitled presentation.gslides'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/MyDrive/Bird Speciees Dataset/AMERICAN GOLDFINCH"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %%
# Setting path and creating empty list
dir = "/content/drive/MyDrive/Bird Speciees Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = cv2.imread(image_path)
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# AMERICAN GOLDFINCH    143
# CARMINE BEE-EATER     131
# BARN OWL              129
# DOWNY WOODPECKER        3
# dtype: int64

# %%
# Storing number of classes
num_classes = len(label_counts)
num_classes
# Out:
# 4

# %%
# Checking input image shape
image_list[0].shape
# Out:
# (224, 224, 3)

# %%
# Checking labels shape 
label_list = np.array(label_list)
label_list.shape
# Out:
# (406,)

# %%
# Splitting dataset
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 224,224,3)
x_test = x_test.reshape( -1, 224,224,3)

# %%
# Label binarizing
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER']

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %%
#adding hidden layers 
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same",input_shape=(224,224,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(32, activation="relu"))
model.add(Dense(num_classes, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 8)       224
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 74, 74, 16)        1168
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 32)                331808
#
#  dense_1 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 337,972
# Trainable params: 337,972
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 3/3 [==============================] - 13s 378ms/step - loss: 1.3119 - accuracy: 0.3359 - val_loss: 1.1989 - val_accuracy: 0.3385
# Epoch 2/50
# 3/3 [==============================] - 0s 70ms/step - loss: 1.2159 - accuracy: 0.3359 - val_loss: 1.0773 - val_accuracy: 0.4000
# Epoch 3/50
# 3/3 [==============================] - 0s 68ms/step - loss: 1.0681 - accuracy: 0.4556 - val_loss: 0.9520 - val_accuracy: 0.6000
# Epoch 4/50
# 3/3 [==============================] - 0s 69ms/step - loss: 1.0103 - accuracy: 0.5637 - val_loss: 0.8808 - val_accuracy: 0.6923
# Epoch 5/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.8935 - accuracy: 0.7336 - val_loss: 0.8079 - val_accuracy: 0.7231
# Epoch 6/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.8294 - accuracy: 0.6988 - val_loss: 0.8345 - val_accuracy: 0.6462
# Epoch 7/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.8814 - accuracy: 0.6602 - val_loss: 0.7445 - val_accuracy: 0.7385
# Epoch 8/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.7413 - accuracy: 0.7915 - val_loss: 0.6881 - val_accuracy: 0.7692
# Epoch 9/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.6758 - accuracy: 0.8185 - val_loss: 0.6130 - val_accuracy: 0.8000
# Epoch 10/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.6431 - accuracy: 0.8263 - val_loss: 0.6432 - val_accuracy: 0.7846
# Epoch 11/50
# 3/3 [==============================] - 0s 73ms/step - loss: 0.6336 - accuracy: 0.8263 - val_loss: 0.5801 - val_accuracy: 0.8000
# Epoch 12/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.5515 - accuracy: 0.8649 - val_loss: 0.4901 - val_accuracy: 0.8769
# Epoch 13/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.4834 - accuracy: 0.8919 - val_loss: 0.4559 - val_accuracy: 0.8462
# Epoch 14/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.4632 - accuracy: 0.8880 - val_loss: 0.4127 - val_accuracy: 0.8615
# Epoch 15/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.4142 - accuracy: 0.8764 - val_loss: 0.4003 - val_accuracy: 0.8308
# Epoch 16/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.3681 - accuracy: 0.8880 - val_loss: 0.4045 - val_accuracy: 0.8308
# Epoch 17/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.4348 - accuracy: 0.8456 - val_loss: 0.3930 - val_accuracy: 0.8615
# Epoch 18/50
# 3/3 [==============================] - 0s 74ms/step - loss: 0.3834 - accuracy: 0.9073 - val_loss: 0.3932 - val_accuracy: 0.8769
# Epoch 19/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.3986 - accuracy: 0.8649 - val_loss: 0.3628 - val_accuracy: 0.8615
# Epoch 20/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.3310 - accuracy: 0.8803 - val_loss: 0.3746 - val_accuracy: 0.8769
# Epoch 21/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.3236 - accuracy: 0.8880 - val_loss: 0.3945 - val_accuracy: 0.8462
# Epoch 22/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.3054 - accuracy: 0.9151 - val_loss: 0.3099 - val_accuracy: 0.8923
# Epoch 23/50
# 3/3 [==============================] - 0s 70ms/step - loss: 0.2762 - accuracy: 0.9305 - val_loss: 0.4079 - val_accuracy: 0.8462
# Epoch 24/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.3717 - accuracy: 0.8456 - val_loss: 0.3863 - val_accuracy: 0.8615
# Epoch 25/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.3335 - accuracy: 0.8803 - val_loss: 0.3238 - val_accuracy: 0.8769
# Epoch 26/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.2974 - accuracy: 0.9112 - val_loss: 0.2564 - val_accuracy: 0.9077
# Epoch 27/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.2034 - accuracy: 0.9537 - val_loss: 0.2745 - val_accuracy: 0.9385
# Epoch 28/50
# 3/3 [==============================] - 0s 72ms/step - loss: 0.2006 - accuracy: 0.9614 - val_loss: 0.3334 - val_accuracy: 0.8923
# Epoch 29/50
# 3/3 [==============================] - 0s 72ms/step - loss: 0.2232 - accuracy: 0.9498 - val_loss: 0.2553 - val_accuracy: 0.9385
# Epoch 30/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1655 - accuracy: 0.9653 - val_loss: 0.2549 - val_accuracy: 0.8923
# Epoch 31/50
# 3/3 [==============================] - 0s 72ms/step - loss: 0.1952 - accuracy: 0.9653 - val_loss: 0.2095 - val_accuracy: 0.9231
# Epoch 32/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1368 - accuracy: 0.9614 - val_loss: 0.2142 - val_accuracy: 0.9077
# Epoch 33/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1390 - accuracy: 0.9653 - val_loss: 0.2038 - val_accuracy: 0.9231
# Epoch 34/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1390 - accuracy: 0.9653 - val_loss: 0.2068 - val_accuracy: 0.9231
# Epoch 35/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1664 - accuracy: 0.9537 - val_loss: 0.1992 - val_accuracy: 0.9231
# Epoch 36/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.1410 - accuracy: 0.9614 - val_loss: 0.1910 - val_accuracy: 0.9231
# Epoch 37/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1186 - accuracy: 0.9768 - val_loss: 0.2138 - val_accuracy: 0.9231
# Epoch 38/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1224 - accuracy: 0.9691 - val_loss: 0.2127 - val_accuracy: 0.9231
# Epoch 39/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1084 - accuracy: 0.9846 - val_loss: 0.1790 - val_accuracy: 0.9231
# Epoch 40/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1102 - accuracy: 0.9730 - val_loss: 0.2056 - val_accuracy: 0.9385
# Epoch 41/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1537 - accuracy: 0.9575 - val_loss: 0.1820 - val_accuracy: 0.9385
# Epoch 42/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1186 - accuracy: 0.9653 - val_loss: 0.1647 - val_accuracy: 0.9231
# Epoch 43/50
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0899 - accuracy: 0.9768 - val_loss: 0.1925 - val_accuracy: 0.9231
# Epoch 44/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0954 - accuracy: 0.9768 - val_loss: 0.2099 - val_accuracy: 0.9231
# Epoch 45/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0926 - accuracy: 0.9846 - val_loss: 0.1818 - val_accuracy: 0.9385
# Epoch 46/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0775 - accuracy: 0.9807 - val_loss: 0.1661 - val_accuracy: 0.9077
# Epoch 47/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0740 - accuracy: 0.9884 - val_loss: 0.1620 - val_accuracy: 0.9231
# Epoch 48/50
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0746 - accuracy: 0.9846 - val_loss: 0.1579 - val_accuracy: 0.9077
# Epoch 49/50
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0686 - accuracy: 0.9846 - val_loss: 0.1613 - val_accuracy: 0.9231
# Epoch 50/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0651 - accuracy: 0.9846 - val_loss: 0.1718 - val_accuracy: 0.9231

# %%
# Saving model
model.save("/content/drive/My Drive/bird_species.h5")

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %%
# Calculating test accuracy
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 3/3 [==============================] - 0s 51ms/step - loss: 0.2860 - accuracy: 0.9146
# Test Accuracy: 91.46341681480408

# %%
# Storing predictions
y_pred = model.predict(x_test)

# %%
# Plotting image to compare
img = array_to_img(x_test[5])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F0BBB00C5D0>

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[5])])
print("Predicted : ",labels[np.argmax(y_pred[5])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER']
# Originally :  BARN OWL
# Predicted :  BARN OWL

# %%
# Plotting image to compare
img1 = array_to_img(x_test[7])
img1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F0BBB00C610>

# %%
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[7])])
print("Predicted : ",labels[np.argmax(y_pred[7])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER']
# Originally :  CARMINE BEE-EATER
# Predicted :  CARMINE BEE-EATER

# %%
# Plotting image to compare
img2 = array_to_img(x_test[20])
img2
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F0BBB02FC90>

# %%
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[20])])
print("Predicted : ",labels[np.argmax(y_pred[20])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER']
# Originally :  BARN OWL
# Predicted :  BARN OWL

# %%
# Plotting image to compare
img3 = array_to_img(x_test[51])
img3
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F0BBB0045D0>

# %%
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[51])])
print("Predicted : ",labels[np.argmax(y_pred[51])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER']
# Originally :  AMERICAN GOLDFINCH
# Predicted :  AMERICAN GOLDFINCH

# %%
# Plotting image to compare
img4 = array_to_img(x_test[79])
img4
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F0BBB02F7D0>

# %%
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[79])])
print("Predicted : ",labels[np.argmax(y_pred[79])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER']
# Originally :  AMERICAN GOLDFINCH
# Predicted :  AMERICAN GOLDFINCH
